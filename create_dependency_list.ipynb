# %%
from pprint import pprint
import json

def add_dependencies(cur_package_dict:dict, parent_packages=[]):
    global package_name_to_req_by
    global deep_req_by
    global package_name_to_reqs
    global deep_reqs

    cur_package_name = cur_package_dict['package_name']
    # managing logic of packages required by cur package
    if cur_package_name not in package_name_to_req_by.keys():
        package_name_to_req_by[cur_package_name] = []
    if len(parent_packages) > 0:
        if deep_req_by:
            package_name_to_req_by[cur_package_name].extend(parent_packages)
        else:
            package_name_to_req_by[cur_package_name].append(parent_packages)

    # managing logic of packages that cur package requires (i.e., dependencies of current package)
    if cur_package_name in package_name_to_reqs.keys():
        return package_name_to_reqs[cur_package_name]
    if len(cur_package_dict['dependencies']) == 0:
        package_name_to_reqs[cur_package_name] = []
        return []
    
    # setting deps. of cur package to top level packages
    top_level_deps = [dep_package_dict['package_name'] for dep_package_dict in cur_package_dict['dependencies']]
    package_name_to_reqs[cur_package_name] = top_level_deps

    if deep_req_by:
        child_will_be_req_by = [cur_package_name] + parent_packages
    else:
        child_will_be_req_by = cur_package_name

    for dependency in cur_package_dict['dependencies']:
        # recursively adding top level deps' deps if deep_reqs is True, otherwise, just execute req_by and reqs logic on next child (i.e., dependency)
        if deep_reqs:
            package_name_to_reqs[cur_package_name].extend(add_dependencies(dependency, child_will_be_req_by))
        else:
            add_dependencies(dependency, child_will_be_req_by)

    # all return statements of this function are useful only if deep_reqs is set to true        
    return top_level_deps

# JSON data
json_data = [
    {
        "key": "aiohttp",
        "package_name": "aiohttp",
        "installed_version": "3.8.3",
        "required_version": "3.8.3",
        "dependencies": [
            {
                "key": "aiosignal",
                "package_name": "aiosignal",
                "installed_version": "1.2.0",
                "required_version": ">=1.1.2",
                "dependencies": [
                    {
                        "key": "frozenlist",
                        "package_name": "frozenlist",
                        "installed_version": "1.3.3",
                        "required_version": ">=1.1.0",
                        "dependencies": []
                    }
                ]
            }
        ]
    },
    {
        "key": "hadooken",
        "package_name": "hadooken",
        "installed_version": "3.8.3",
        "required_version": "3.8.3",
        "dependencies": [
            {
                "key": "aiosignal",
                "package_name": "aiosignal",
                "installed_version": "1.2.0",
                "required_version": ">=1.1.2",
                "dependencies": [
                    {
                        "key": "frozenlist",
                        "package_name": "frozenlist",
                        "installed_version": "1.3.3",
                        "required_version": ">=1.1.0",
                        "dependencies": []
                    }
                ]
            }
        ]
    }
]
# Out:
# {'Bottleneck': ['numpy'],
#  'Flask': ['click',
#            'importlib-metadata',
#            'itsdangerous',
#            'Jinja2',
#            'Werkzeug',
#            'colorama',
#            'zipp',
#            'MarkupSafe',
#            'MarkupSafe'],
#  'Flask-Compress': ['brotli',
#                     'flask',
#                     'click',
#                     'importlib-metadata',
#                     'itsdangerous',
#                     'Jinja2',
#                     'Werkzeug',
#                     'colorama',
#                     'zipp',
#                     'MarkupSafe',
#                     'MarkupSafe'],
#  'Jinja2': ['MarkupSafe'],
#  'MarkupSafe': [],
#  'Pillow': [],
#  'PyQt5': ['PyQt5-sip'],
#  'PyQt5-sip': [],
#  'PySocks': [],
#  'PyYAML': [],
#  'Send2Trash': [],
#  'Werkzeug': ['MarkupSafe'],
#  'absl-py': [],
#  'aiohttp': ['aiosignal',
#              'async-timeout',
#              'attrs',
#              'charset-normalizer',
#              'frozenlist',
#              'multidict',
#              'yarl',
#              'frozenlist',
#              'idna',
#              'multidict'],
#  'aiosignal': ['frozenlist'],
#  'anaconda-client': ['clyent',
#                      'conda-package-handling',
#                      'defusedxml',
#                      'nbformat',
#                      'python-dateutil',
#                      'pytz',
#                      'pyyaml',
#                      'requests',
#                      'requests-toolbelt',
#                      'setuptools',
#                      'six',
#                      'tqdm',
#                      'urllib3',
#                      'conda-package-streaming',
#                      'requests',
#                      'zstandard',
#                      'certifi',
#                      'charset-normalizer',
#                      'idna',
#                      'urllib3',
#                      'fastjsonschema',
#                      'jsonschema',
#                      'jupyter-core',
#                      'traitlets',
#                      'attrs',
#                      'pyrsistent',
#                      'platformdirs',
#                      'pywin32',
#                      'traitlets',
#                      'six',
#                      'certifi',
#                      'charset-normalizer',
#                      'idna',
#                      'urllib3',
#                      'requests',
#                      'certifi',
#                      'charset-normalizer',
#                      'idna',
#                      'urllib3',
#                      'colorama'],
#  'ansi2html': [],
#  'ansicon': [],
#  'anyio': ['idna', 'sniffio'],
#  'appdirs': [],
#  'argon2-cffi': ['argon2-cffi-bindings', 'cffi', 'pycparser'],
#  'argon2-cffi-bindings': ['cffi', 'pycparser'],
#  'arrow': ['python-dateutil', 'six'],
#  'asttokens': ['six'],
#  'astunparse': ['six', 'wheel'],
#  'async-timeout': [],
#  'attrs': [],
#  'babel': ['pytz'],
#  'backcall': [],
#  'beautifulsoup4': ['soupsieve'],
#  'bleach': ['packaging', 'six', 'webencodings'],
#  'blessed': ['jinxed', 'six', 'wcwidth', 'ansicon'],
#  'blinker': [],
#  'boltons': [],
#  'brotli': [],
#  'brotlipy': ['cffi', 'pycparser'],
#  'cachetools': [],
#  'certifi': [],
#  'cffi': ['pycparser'],
#  'chardet': [],
#  'charset-normalizer': [],
#  'chart-studio': ['plotly',
#                   'requests',
#                   'retrying',
#                   'six',
#                   'tenacity',
#                   'certifi',
#                   'charset-normalizer',
#                   'idna',
#                   'urllib3',
#                   'six'],
#  'click': ['colorama'],
#  'clyent': [],
#  'colorama': [],
#  'colorlover': [],
#  'comm': ['traitlets'],
#  'commonmark': [],
#  'conda': ['menuinst',
#            'pluggy',
#            'pycosat',
#            'requests',
#            'ruamel.yaml',
#            'tqdm',
#            'certifi',
#            'charset-normalizer',
#            'idna',
#            'urllib3',
#            'ruamel.yaml.clib',
#            'colorama'],
#  'conda-build': ['beautifulsoup4',
#                  'chardet',
#                  'conda',
#                  'filelock',
#                  'glob2',
#                  'jinja2',
#                  'libarchive-c',
#                  'packaging',
#                  'pkginfo',
#                  'psutil',
#                  'pytz',
#                  'pyyaml',
#                  'requests',
#                  'six',
#                  'tomli',
#                  'tqdm',
#                  'soupsieve',
#                  'menuinst',
#                  'pluggy',
#                  'pycosat',
#                  'requests',
#                  'ruamel.yaml',
#                  'tqdm',
#                  'certifi',
#                  'charset-normalizer',
#                  'idna',
#                  'urllib3',
#                  'ruamel.yaml.clib',
#                  'colorama',
#                  'MarkupSafe',
#                  'certifi',
#                  'charset-normalizer',
#                  'idna',
#                  'urllib3',
#                  'colorama'],
#  'conda-package-handling': ['conda-package-streaming',
#                             'requests',
#                             'zstandard',
#                             'certifi',
#                             'charset-normalizer',
#                             'idna',
#                             'urllib3'],
#  'conda-package-streaming': ['requests',
#                              'zstandard',
#                              'certifi',
#                              'charset-normalizer',
#                              'idna',
#                              'urllib3'],
#  'contourpy': ['numpy'],
#  'croniter': ['python-dateutil', 'six'],
#  'cryptography': ['cffi', 'pycparser'],
#  'cufflinks': ['colorlover',
#                'ipython',
#                'ipywidgets',
#                'numpy',
#                'pandas',
#                'plotly',
#                'setuptools',
#                'six',
#                'backcall',
#                'colorama',
#                'decorator',
#                'jedi',
#                'matplotlib-inline',
#                'pickleshare',
#                'prompt-toolkit',
#                'pygments',
#                'stack-data',
#                'traitlets',
#                'typing-extensions',
#                'parso',
#                'traitlets',
#                'wcwidth',
#                'asttokens',
#                'executing',
#                'pure-eval',
#                'six',
#                'ipykernel',
#                'ipython',
#                'ipython-genutils',
#                'jupyterlab-widgets',
#                'traitlets',
#                'widgetsnbextension',
#                'comm',
#                'debugpy',
#                'ipython',
#                'jupyter-client',
#                'matplotlib-inline',
#                'nest-asyncio',
#                'packaging',
#                'psutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'traitlets',
#                'backcall',
#                'colorama',
#                'decorator',
#                'jedi',
#                'matplotlib-inline',
#                'pickleshare',
#                'prompt-toolkit',
#                'pygments',
#                'stack-data',
#                'traitlets',
#                'typing-extensions',
#                'parso',
#                'traitlets',
#                'wcwidth',
#                'asttokens',
#                'executing',
#                'pure-eval',
#                'six',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'traitlets',
#                'backcall',
#                'colorama',
#                'decorator',
#                'jedi',
#                'matplotlib-inline',
#                'pickleshare',
#                'prompt-toolkit',
#                'pygments',
#                'stack-data',
#                'traitlets',
#                'typing-extensions',
#                'parso',
#                'traitlets',
#                'wcwidth',
#                'asttokens',
#                'executing',
#                'pure-eval',
#                'six',
#                'notebook',
#                'argon2-cffi',
#                'ipykernel',
#                'ipython-genutils',
#                'jinja2',
#                'jupyter-client',
#                'jupyter-core',
#                'nbclassic',
#                'nbconvert',
#                'nbformat',
#                'nest-asyncio',
#                'prometheus-client',
#                'pyzmq',
#                'Send2Trash',
#                'terminado',
#                'tornado',
#                'traitlets',
#                'argon2-cffi-bindings',
#                'cffi',
#                'pycparser',
#                'comm',
#                'debugpy',
#                'ipython',
#                'jupyter-client',
#                'matplotlib-inline',
#                'nest-asyncio',
#                'packaging',
#                'psutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'traitlets',
#                'backcall',
#                'colorama',
#                'decorator',
#                'jedi',
#                'matplotlib-inline',
#                'pickleshare',
#                'prompt-toolkit',
#                'pygments',
#                'stack-data',
#                'traitlets',
#                'typing-extensions',
#                'parso',
#                'traitlets',
#                'wcwidth',
#                'asttokens',
#                'executing',
#                'pure-eval',
#                'six',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'traitlets',
#                'MarkupSafe',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'argon2-cffi',
#                'ipykernel',
#                'ipython-genutils',
#                'jinja2',
#                'jupyter-client',
#                'jupyter-core',
#                'jupyter-server',
#                'nbconvert',
#                'nbformat',
#                'nest-asyncio',
#                'notebook-shim',
#                'prometheus-client',
#                'pyzmq',
#                'Send2Trash',
#                'terminado',
#                'tornado',
#                'traitlets',
#                'argon2-cffi-bindings',
#                'cffi',
#                'pycparser',
#                'comm',
#                'debugpy',
#                'ipython',
#                'jupyter-client',
#                'matplotlib-inline',
#                'nest-asyncio',
#                'packaging',
#                'psutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'traitlets',
#                'backcall',
#                'colorama',
#                'decorator',
#                'jedi',
#                'matplotlib-inline',
#                'pickleshare',
#                'prompt-toolkit',
#                'pygments',
#                'stack-data',
#                'traitlets',
#                'typing-extensions',
#                'parso',
#                'traitlets',
#                'wcwidth',
#                'asttokens',
#                'executing',
#                'pure-eval',
#                'six',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'traitlets',
#                'MarkupSafe',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'anyio',
#                'argon2-cffi',
#                'jinja2',
#                'jupyter-client',
#                'jupyter-core',
#                'nbconvert',
#                'nbformat',
#                'packaging',
#                'prometheus-client',
#                'pywinpty',
#                'pyzmq',
#                'Send2Trash',
#                'terminado',
#                'tornado',
#                'traitlets',
#                'websocket-client',
#                'idna',
#                'sniffio',
#                'argon2-cffi-bindings',
#                'cffi',
#                'pycparser',
#                'MarkupSafe',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'beautifulsoup4',
#                'bleach',
#                'defusedxml',
#                'entrypoints',
#                'jinja2',
#                'jupyter-core',
#                'jupyterlab-pygments',
#                'lxml',
#                'MarkupSafe',
#                'mistune',
#                'nbclient',
#                'nbformat',
#                'packaging',
#                'pandocfilters',
#                'pygments',
#                'tinycss2',
#                'traitlets',
#                'soupsieve',
#                'packaging',
#                'six',
#                'webencodings',
#                'MarkupSafe',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'pygments',
#                'jupyter-client',
#                'nbformat',
#                'nest-asyncio',
#                'traitlets',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'webencodings',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'pywinpty',
#                'tornado',
#                'six',
#                'beautifulsoup4',
#                'bleach',
#                'defusedxml',
#                'entrypoints',
#                'jinja2',
#                'jupyter-core',
#                'jupyterlab-pygments',
#                'lxml',
#                'MarkupSafe',
#                'mistune',
#                'nbclient',
#                'nbformat',
#                'packaging',
#                'pandocfilters',
#                'pygments',
#                'tinycss2',
#                'traitlets',
#                'soupsieve',
#                'packaging',
#                'six',
#                'webencodings',
#                'MarkupSafe',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'pygments',
#                'jupyter-client',
#                'nbformat',
#                'nest-asyncio',
#                'traitlets',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'webencodings',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'jupyter-server',
#                'anyio',
#                'argon2-cffi',
#                'jinja2',
#                'jupyter-client',
#                'jupyter-core',
#                'nbconvert',
#                'nbformat',
#                'packaging',
#                'prometheus-client',
#                'pywinpty',
#                'pyzmq',
#                'Send2Trash',
#                'terminado',
#                'tornado',
#                'traitlets',
#                'websocket-client',
#                'idna',
#                'sniffio',
#                'argon2-cffi-bindings',
#                'cffi',
#                'pycparser',
#                'MarkupSafe',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'beautifulsoup4',
#                'bleach',
#                'defusedxml',
#                'entrypoints',
#                'jinja2',
#                'jupyter-core',
#                'jupyterlab-pygments',
#                'lxml',
#                'MarkupSafe',
#                'mistune',
#                'nbclient',
#                'nbformat',
#                'packaging',
#                'pandocfilters',
#                'pygments',
#                'tinycss2',
#                'traitlets',
#                'soupsieve',
#                'packaging',
#                'six',
#                'webencodings',
#                'MarkupSafe',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'pygments',
#                'jupyter-client',
#                'nbformat',
#                'nest-asyncio',
#                'traitlets',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'webencodings',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'pywinpty',
#                'tornado',
#                'six',
#                'pywinpty',
#                'tornado',
#                'beautifulsoup4',
#                'bleach',
#                'defusedxml',
#                'entrypoints',
#                'jinja2',
#                'jupyter-core',
#                'jupyterlab-pygments',
#                'lxml',
#                'MarkupSafe',
#                'mistune',
#                'nbclient',
#                'nbformat',
#                'packaging',
#                'pandocfilters',
#                'pygments',
#                'tinycss2',
#                'traitlets',
#                'soupsieve',
#                'packaging',
#                'six',
#                'webencodings',
#                'MarkupSafe',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'pygments',
#                'jupyter-client',
#                'nbformat',
#                'nest-asyncio',
#                'traitlets',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'webencodings',
#                'fastjsonschema',
#                'jsonschema',
#                'jupyter-core',
#                'traitlets',
#                'attrs',
#                'pyrsistent',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'pywinpty',
#                'tornado',
#                'numpy',
#                'python-dateutil',
#                'pytz',
#                'six',
#                'tenacity'],
#  'cycler': [],
#  'dash': ['Flask',
#           'plotly',
#           'click',
#           'importlib-metadata',
#           'itsdangerous',
#           'Jinja2',
#           'Werkzeug',
#           'colorama',
#           'zipp',
#           'MarkupSafe',
#           'MarkupSafe',
#           'tenacity'],
#  'dateutils': ['python-dateutil', 'pytz', 'six'],
#  'debugpy': [],
#  'decorator': [],
#  'deepdiff': ['ordered-set'],
#  'defusedxml': [],
#  'entrypoints': [],
#  'executing': [],
#  'fastapi': ['pydantic',
#              'starlette',
#              'typing-extensions',
#              'anyio',
#              'typing-extensions',
#              'idna',
#              'sniffio'],
#  'fastdup': ['numpy',
#              'opencv-python-headless',
#              'packaging',
#              'pandas',
#              'pillow',
#              'pyyaml',
#              'requests',
#              'sentry-sdk',
#              'tqdm',
#              'numpy',
#              'numpy',
#              'numpy',
#              'numpy',
#              'python-dateutil',
#              'pytz',
#              'six',
#              'certifi',
#              'charset-normalizer',
#              'idna',
#              'urllib3',
#              'certifi',
#              'urllib3',
#              'urllib3',
#              'colorama'],
#  'fastjsonschema': [],
#  'filelock': [],
#  'flask': ['click',
#            'importlib-metadata',
#            'itsdangerous',
#            'Jinja2',
#            'Werkzeug',
#            'colorama',
#            'zipp',
#            'MarkupSafe',
#            'MarkupSafe'],
#  'flatbuffers': [],
#  'fonttools': [],
#  'frozenlist': [],
#  'fsspec': [],
#  'future': [],
#  'gast': [],
#  'gdown': ['beautifulsoup4',
#            'filelock',
#            'requests',
#            'six',
#            'tqdm',
#            'soupsieve',
#            'certifi',
#            'charset-normalizer',
#            'idna',
#            'urllib3',
#            'colorama'],
#  'glob2': [],
#  'google-auth': ['cachetools',
#                  'pyasn1-modules',
#                  'rsa',
#                  'six',
#                  'pyasn1',
#                  'pyasn1'],
#  'google-auth-oauthlib': ['google-auth',
#                           'requests-oauthlib',
#                           'cachetools',
#                           'pyasn1-modules',
#                           'rsa',
#                           'six',
#                           'pyasn1',
#                           'pyasn1',
#                           'oauthlib',
#                           'requests',
#                           'certifi',
#                           'charset-normalizer',
#                           'idna',
#                           'urllib3'],
#  'google-pasta': ['six'],
#  'graphviz': [],
#  'grpcio': ['six'],
#  'h11': [],
#  'h5py': ['numpy'],
#  'helium': ['selenium', 'urllib3'],
#  'idna': [],
#  'image-to-numpy': ['numpy', 'pillow'],
#  'imagesize': [],
#  'importlib-metadata': ['zipp'],
#  'importlib-resources': ['zipp'],
#  'inquirer': ['blessed',
#               'python-editor',
#               'readchar',
#               'jinxed',
#               'six',
#               'wcwidth',
#               'ansicon',
#               'setuptools'],
#  'ipykernel': ['comm',
#                'debugpy',
#                'ipython',
#                'jupyter-client',
#                'matplotlib-inline',
#                'nest-asyncio',
#                'packaging',
#                'psutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'traitlets',
#                'backcall',
#                'colorama',
#                'decorator',
#                'jedi',
#                'matplotlib-inline',
#                'pickleshare',
#                'prompt-toolkit',
#                'pygments',
#                'stack-data',
#                'traitlets',
#                'typing-extensions',
#                'parso',
#                'traitlets',
#                'wcwidth',
#                'asttokens',
#                'executing',
#                'pure-eval',
#                'six',
#                'importlib-metadata',
#                'jupyter-core',
#                'python-dateutil',
#                'pyzmq',
#                'tornado',
#                'traitlets',
#                'zipp',
#                'platformdirs',
#                'pywin32',
#                'traitlets',
#                'six',
#                'traitlets'],
#  'ipython': ['backcall',
#              'colorama',
#              'decorator',
#              'jedi',
#              'matplotlib-inline',
#              'pickleshare',
#              'prompt-toolkit',
#              'pygments',
#              'stack-data',
#              'traitlets',
#              'typing-extensions',
#              'parso',
#              'traitlets',
#              'wcwidth',
#              'asttokens',
#              'executing',
#              'pure-eval',
#              'six'],
#  'ipython-genutils': [],
#  'ipywidgets': ['ipykernel',
#                 'ipython',
#                 'ipython-genutils',
#                 'jupyterlab-widgets',
#                 'traitlets',
#                 'widgetsnbextension',
#                 'comm',
#                 'debugpy',
#                 'ipython',
#                 'jupyter-client',
#                 'matplotlib-inline',
#                 'nest-asyncio',
#                 'packaging',
#                 'psutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'traitlets',
#                 'backcall',
#                 'colorama',
#                 'decorator',
#                 'jedi',
#                 'matplotlib-inline',
#                 'pickleshare',
#                 'prompt-toolkit',
#                 'pygments',
#                 'stack-data',
#                 'traitlets',
#                 'typing-extensions',
#                 'parso',
#                 'traitlets',
#                 'wcwidth',
#                 'asttokens',
#                 'executing',
#                 'pure-eval',
#                 'six',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'traitlets',
#                 'backcall',
#                 'colorama',
#                 'decorator',
#                 'jedi',
#                 'matplotlib-inline',
#                 'pickleshare',
#                 'prompt-toolkit',
#                 'pygments',
#                 'stack-data',
#                 'traitlets',
#                 'typing-extensions',
#                 'parso',
#                 'traitlets',
#                 'wcwidth',
#                 'asttokens',
#                 'executing',
#                 'pure-eval',
#                 'six',
#                 'notebook',
#                 'argon2-cffi',
#                 'ipykernel',
#                 'ipython-genutils',
#                 'jinja2',
#                 'jupyter-client',
#                 'jupyter-core',
#                 'nbclassic',
#                 'nbconvert',
#                 'nbformat',
#                 'nest-asyncio',
#                 'prometheus-client',
#                 'pyzmq',
#                 'Send2Trash',
#                 'terminado',
#                 'tornado',
#                 'traitlets',
#                 'argon2-cffi-bindings',
#                 'cffi',
#                 'pycparser',
#                 'comm',
#                 'debugpy',
#                 'ipython',
#                 'jupyter-client',
#                 'matplotlib-inline',
#                 'nest-asyncio',
#                 'packaging',
#                 'psutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'traitlets',
#                 'backcall',
#                 'colorama',
#                 'decorator',
#                 'jedi',
#                 'matplotlib-inline',
#                 'pickleshare',
#                 'prompt-toolkit',
#                 'pygments',
#                 'stack-data',
#                 'traitlets',
#                 'typing-extensions',
#                 'parso',
#                 'traitlets',
#                 'wcwidth',
#                 'asttokens',
#                 'executing',
#                 'pure-eval',
#                 'six',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'traitlets',
#                 'MarkupSafe',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'argon2-cffi',
#                 'ipykernel',
#                 'ipython-genutils',
#                 'jinja2',
#                 'jupyter-client',
#                 'jupyter-core',
#                 'jupyter-server',
#                 'nbconvert',
#                 'nbformat',
#                 'nest-asyncio',
#                 'notebook-shim',
#                 'prometheus-client',
#                 'pyzmq',
#                 'Send2Trash',
#                 'terminado',
#                 'tornado',
#                 'traitlets',
#                 'argon2-cffi-bindings',
#                 'cffi',
#                 'pycparser',
#                 'comm',
#                 'debugpy',
#                 'ipython',
#                 'jupyter-client',
#                 'matplotlib-inline',
#                 'nest-asyncio',
#                 'packaging',
#                 'psutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'traitlets',
#                 'backcall',
#                 'colorama',
#                 'decorator',
#                 'jedi',
#                 'matplotlib-inline',
#                 'pickleshare',
#                 'prompt-toolkit',
#                 'pygments',
#                 'stack-data',
#                 'traitlets',
#                 'typing-extensions',
#                 'parso',
#                 'traitlets',
#                 'wcwidth',
#                 'asttokens',
#                 'executing',
#                 'pure-eval',
#                 'six',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'traitlets',
#                 'MarkupSafe',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'anyio',
#                 'argon2-cffi',
#                 'jinja2',
#                 'jupyter-client',
#                 'jupyter-core',
#                 'nbconvert',
#                 'nbformat',
#                 'packaging',
#                 'prometheus-client',
#                 'pywinpty',
#                 'pyzmq',
#                 'Send2Trash',
#                 'terminado',
#                 'tornado',
#                 'traitlets',
#                 'websocket-client',
#                 'idna',
#                 'sniffio',
#                 'argon2-cffi-bindings',
#                 'cffi',
#                 'pycparser',
#                 'MarkupSafe',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'beautifulsoup4',
#                 'bleach',
#                 'defusedxml',
#                 'entrypoints',
#                 'jinja2',
#                 'jupyter-core',
#                 'jupyterlab-pygments',
#                 'lxml',
#                 'MarkupSafe',
#                 'mistune',
#                 'nbclient',
#                 'nbformat',
#                 'packaging',
#                 'pandocfilters',
#                 'pygments',
#                 'tinycss2',
#                 'traitlets',
#                 'soupsieve',
#                 'packaging',
#                 'six',
#                 'webencodings',
#                 'MarkupSafe',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'pygments',
#                 'jupyter-client',
#                 'nbformat',
#                 'nest-asyncio',
#                 'traitlets',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'webencodings',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'pywinpty',
#                 'tornado',
#                 'six',
#                 'beautifulsoup4',
#                 'bleach',
#                 'defusedxml',
#                 'entrypoints',
#                 'jinja2',
#                 'jupyter-core',
#                 'jupyterlab-pygments',
#                 'lxml',
#                 'MarkupSafe',
#                 'mistune',
#                 'nbclient',
#                 'nbformat',
#                 'packaging',
#                 'pandocfilters',
#                 'pygments',
#                 'tinycss2',
#                 'traitlets',
#                 'soupsieve',
#                 'packaging',
#                 'six',
#                 'webencodings',
#                 'MarkupSafe',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'pygments',
#                 'jupyter-client',
#                 'nbformat',
#                 'nest-asyncio',
#                 'traitlets',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'webencodings',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'jupyter-server',
#                 'anyio',
#                 'argon2-cffi',
#                 'jinja2',
#                 'jupyter-client',
#                 'jupyter-core',
#                 'nbconvert',
#                 'nbformat',
#                 'packaging',
#                 'prometheus-client',
#                 'pywinpty',
#                 'pyzmq',
#                 'Send2Trash',
#                 'terminado',
#                 'tornado',
#                 'traitlets',
#                 'websocket-client',
#                 'idna',
#                 'sniffio',
#                 'argon2-cffi-bindings',
#                 'cffi',
#                 'pycparser',
#                 'MarkupSafe',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'beautifulsoup4',
#                 'bleach',
#                 'defusedxml',
#                 'entrypoints',
#                 'jinja2',
#                 'jupyter-core',
#                 'jupyterlab-pygments',
#                 'lxml',
#                 'MarkupSafe',
#                 'mistune',
#                 'nbclient',
#                 'nbformat',
#                 'packaging',
#                 'pandocfilters',
#                 'pygments',
#                 'tinycss2',
#                 'traitlets',
#                 'soupsieve',
#                 'packaging',
#                 'six',
#                 'webencodings',
#                 'MarkupSafe',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'pygments',
#                 'jupyter-client',
#                 'nbformat',
#                 'nest-asyncio',
#                 'traitlets',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'webencodings',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'pywinpty',
#                 'tornado',
#                 'six',
#                 'pywinpty',
#                 'tornado',
#                 'beautifulsoup4',
#                 'bleach',
#                 'defusedxml',
#                 'entrypoints',
#                 'jinja2',
#                 'jupyter-core',
#                 'jupyterlab-pygments',
#                 'lxml',
#                 'MarkupSafe',
#                 'mistune',
#                 'nbclient',
#                 'nbformat',
#                 'packaging',
#                 'pandocfilters',
#                 'pygments',
#                 'tinycss2',
#                 'traitlets',
#                 'soupsieve',
#                 'packaging',
#                 'six',
#                 'webencodings',
#                 'MarkupSafe',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'pygments',
#                 'jupyter-client',
#                 'nbformat',
#                 'nest-asyncio',
#                 'traitlets',
#                 'importlib-metadata',
#                 'jupyter-core',
#                 'python-dateutil',
#                 'pyzmq',
#                 'tornado',
#                 'traitlets',
#                 'zipp',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'six',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'webencodings',
#                 'fastjsonschema',
#                 'jsonschema',
#                 'jupyter-core',
#                 'traitlets',
#                 'attrs',
#                 'pyrsistent',
#                 'platformdirs',
#                 'pywin32',
#                 'traitlets',
#                 'pywinpty',
#                 'tornado'],
#  'itsdangerous': [],
#  'jedi': ['parso'],
#  'jinja2': ['MarkupSafe'],
#  'jinxed': ['ansicon'],
#  'joblib': [],
#  'json5': [],
#  'jsonpatch': ['jsonpointer'],
#  'jsonpointer': [],
#  'jsonschema': ['attrs', 'pyrsistent'],
#  'jupyter': ['ipykernel',
#              'ipywidgets',
#              'jupyter-console',
#              'nbconvert',
#              'notebook',
#              'qtconsole',
#              'comm',
#              'debugpy',
#              'ipython',
#              'jupyter-client',
#              'matplotlib-inline',
#              'nest-asyncio',
#              'packaging',
#              'psutil',
#              'pyzmq',
#              'tornado',
#              'traitlets',
#              'traitlets',
#              'backcall',
#              'colorama',
#              'decorator',
#              'jedi',
#              'matplotlib-inline',
#              'pickleshare',
#              'prompt-toolkit',
#              'pygments',
#              'stack-data',
#              'traitlets',
#              'typing-extensions',
#              'parso',
#              'traitlets',
#              'wcwidth',
#              'asttokens',
#              'executing',
#              'pure-eval',
#              'six',
#              'importlib-metadata',
#              'jupyter-core',
#              'python-dateutil',
#              'pyzmq',
#              'tornado',
#              'traitlets',
#              'zipp',
#              'platformdirs',
#              'pywin32',
#              'traitlets',
#              'six',
#              'traitlets',
#              'ipykernel',
#              'ipython',
#              'ipython-genutils',
#              'jupyterlab-widgets',
#              'traitlets',
#              'widgetsnbextension',
#              'comm',
#              'debugpy',
#              'ipython',
#              'jupyter-client',
#              'matplotlib-inline',
#              'nest-asyncio',
#              'packaging',
#              'psutil',
#              'pyzmq',
#              'tornado',
#              'traitlets',
#              'traitlets',
#              'backcall',
#              'colorama',
#              'decorator',
#              'jedi',
#              'matplotlib-inline',
#              'pickleshare',
#              'prompt-toolkit',
#              'pygments',
#              'stack-data',
#              'traitlets',
#              'typing-extensions',
#              'parso',
#              'traitlets',
#              'wcwidth',
#              'asttokens',
#              'executing',
#              'pure-eval',
#              'six',
#              'importlib-metadata',
#              'jupyter-core',
#              'python-dateutil',
#              'pyzmq',
#              'tornado',
#              'traitlets',
#              'zipp',
#              'platformdirs',
#              'pywin32',
#              'traitlets',
#              'six',
#              'traitlets',
#              'backcall',
#              'colorama',
#              'decorator',
#              'jedi',
#              'matplotlib-inline',
#              'pickleshare',
#              'prompt-toolkit',
#              'pygments',
#              'stack-data',
#              'traitlets',
#              'typing-extensions',
#              'parso',
#              'traitlets',
#              'wcwidth',
#              'asttokens',
#              'executing',
#              'pure-eval',
#              'six',
#              'notebook',
#              'argon2-cffi',
#              'ipykernel',
#              'ipython-genutils',
#              'jinja2',
# ...
#  'pandas': ['cufflinks', 'fastdup'],
#  'pandocfilters': ['nbconvert',
#                    'jupyter-server',
#                    'nbclassic',
#                    'notebook',
#                    'widgetsnbextension',
#                    'ipywidgets',
#                    'cufflinks'],
#  'parso': ['jedi', 'ipython', 'cufflinks'],
#  'pickleshare': ['ipython', 'cufflinks'],
#  'pillow': ['fastdup', 'image-to-numpy', 'matplotlib', 'torchvision'],
#  'pip': [],
#  'pipdeptree': [],
#  'pkginfo': ['conda-build'],
#  'platformdirs': ['jupyter-core', 'nbformat', 'anaconda-client'],
#  'plotly': ['chart-studio', 'cufflinks', 'dash', 'jupyter-dash'],
#  'pluggy': ['conda', 'conda-build'],
#  'ply': ['sip'],
#  'pooch': [],
#  'prometheus-client': ['jupyter-server',
#                        'nbclassic',
#                        'notebook',
#                        'widgetsnbextension',
#                        'ipywidgets',
#                        'cufflinks',
#                        'nbclassic',
#                        'notebook',
#                        'widgetsnbextension',
#                        'ipywidgets',
#                        'cufflinks',
#                        'notebook',
#                        'widgetsnbextension',
#                        'ipywidgets',
#                        'cufflinks'],
#  'prompt-toolkit': ['ipython', 'cufflinks', 'jupyter-console', 'jupyter'],
#  'protobuf': ['tensorflow',
#               'retina-face',
#               'tensorboard',
#               'tensorflow',
#               'retina-face'],
#  'psutil': ['conda-build', 'ipykernel', 'ipywidgets', 'cufflinks', 'lightning'],
#  'pure-eval': ['stack-data', 'ipython', 'cufflinks'],
#  'pyOpenSSL': [],
#  'pyasn1': ['pyasn1-modules',
#             'google-auth',
#             'tensorboard',
#             'tensorflow',
#             'retina-face',
#             'rsa',
#             'google-auth',
#             'tensorboard',
#             'tensorflow',
#             'retina-face'],
#  'pyasn1-modules': ['google-auth', 'tensorboard', 'tensorflow', 'retina-face'],
#  'pycosat': ['conda', 'conda-build'],
#  'pycparser': ['cffi', 'brotlipy'],
#  'pydantic': ['fastapi', 'lightning', 'lightning'],
#  'pygments': ['ipython',
#               'cufflinks',
#               'jupyterlab-pygments',
#               'nbconvert',
#               'jupyter-server',
#               'nbclassic',
#               'notebook',
#               'widgetsnbextension',
#               'ipywidgets',
#               'cufflinks',
#               'nbconvert',
#               'jupyter-server',
#               'nbclassic',
#               'notebook',
#               'widgetsnbextension',
#               'ipywidgets',
#               'cufflinks',
#               'jupyter-console',
#               'jupyter',
#               'qtconsole',
#               'jupyter',
#               'rich',
#               'lightning-cloud',
#               'lightning'],
#  'pyjwt': ['lightning-cloud', 'lightning'],
#  'pyparsing': ['matplotlib'],
#  'pyrsistent': ['jsonschema', 'nbformat', 'anaconda-client'],
#  'python-dateutil': ['anaconda-client',
#                      'jupyter-client',
#                      'ipykernel',
#                      'ipywidgets',
#                      'cufflinks',
#                      'pandas',
#                      'cufflinks',
#                      'arrow',
#                      'lightning',
#                      'croniter',
#                      'lightning',
#                      'dateutils',
#                      'lightning',
#                      'matplotlib'],
#  'python-dotenv': ['webdriver-manager'],
#  'python-editor': ['inquirer', 'lightning'],
#  'python-multipart': ['lightning-cloud', 'lightning'],
#  'pytorch-lightning': ['lightning'],
#  'pytz': ['anaconda-client',
#           'conda-build',
#           'pandas',
#           'cufflinks',
#           'babel',
#           'jupyterlab-server',
#           'jupyterlab',
#           'dateutils',
#           'lightning'],
#  'pywin32': ['jupyter-core', 'nbformat', 'anaconda-client'],
#  'pywinpty': ['jupyter-server',
#               'nbclassic',
#               'notebook',
#               'widgetsnbextension',
#               'ipywidgets',
#               'cufflinks',
#               'terminado',
#               'jupyter-server',
#               'nbclassic',
#               'notebook',
#               'widgetsnbextension',
#               'ipywidgets',
#               'cufflinks'],
#  'pyyaml': ['anaconda-client', 'conda-build', 'fastdup'],
#  'pyzmq': ['jupyter-client',
#            'ipykernel',
#            'ipywidgets',
#            'cufflinks',
#            'ipykernel',
#            'ipywidgets',
#            'cufflinks',
#            'jupyter-server',
#            'nbclassic',
#            'notebook',
#            'widgetsnbextension',
#            'ipywidgets',
#            'cufflinks',
#            'nbclassic',
#            'notebook',
#            'widgetsnbextension',
#            'ipywidgets',
#            'cufflinks',
#            'notebook',
#            'widgetsnbextension',
#            'ipywidgets',
#            'cufflinks',
#            'jupyter-console',
#            'jupyter',
#            'qtconsole',
#            'jupyter'],
#  'qtconsole': ['jupyter'],
#  'qtpy': ['qtconsole', 'jupyter'],
#  'readchar': ['inquirer', 'lightning'],
#  'regex': ['nltk'],
#  'requests': ['conda-package-streaming',
#               'conda-package-handling',
#               'anaconda-client',
#               'anaconda-client',
#               'requests-toolbelt',
#               'anaconda-client',
#               'chart-studio',
#               'conda',
#               'conda-build',
#               'conda-build',
#               'fastdup',
#               'jupyter-dash',
#               'jupyterlab-server',
#               'jupyterlab',
#               'lightning-cloud',
#               'lightning',
#               'lightning',
#               'pooch',
#               'gdown',
#               'retina-face',
#               'requests-oauthlib',
#               'google-auth-oauthlib',
#               'tensorboard',
#               'tensorflow',
#               'retina-face',
#               'tensorboard',
#               'tensorflow',
#               'retina-face',
#               'torchvision',
#               'webdriver-manager'],
#  'requests-oauthlib': ['google-auth-oauthlib',
#                        'tensorboard',
#                        'tensorflow',
#                        'retina-face'],
#  'requests-toolbelt': ['anaconda-client'],
#  'retina-face': [],
#  'retrying': ['chart-studio', 'jupyter-dash'],
#  'rich': ['lightning-cloud', 'lightning', 'lightning'],
#  'rsa': ['google-auth', 'tensorboard', 'tensorflow', 'retina-face'],
#  'ruamel.yaml': ['conda', 'conda-build'],
#  'ruamel.yaml.clib': ['ruamel.yaml', 'conda', 'conda-build'],
#  'scikit-learn': [],
#  'scipy': ['scikit-learn'],
#  'selenium': ['helium'],
#  'sentry-sdk': ['fastdup'],
#  'setuptools': ['anaconda-client',
#                 'cufflinks',
#                 'readchar',
#                 'inquirer',
#                 'lightning',
#                 'tensorflow',
#                 'retina-face',
#                 'tensorboard',
#                 'tensorflow',
#                 'retina-face',
#                 'sip'],
#  'simple-hierarchy': [],
#  'sip': [],
#  'six': ['python-dateutil',
#          'anaconda-client',
#          'anaconda-client',
#          'retrying',
#          'chart-studio',
#          'chart-studio',
#          'conda-build',
#          'asttokens',
#          'stack-data',
#          'ipython',
#          'cufflinks',
#          'bleach',
#          'nbconvert',
#          'jupyter-server',
#          'nbclassic',
#          'notebook',
#          'widgetsnbextension',
#          'ipywidgets',
#          'cufflinks',
#          'websocket-client',
#          'jupyter-server',
#          'nbclassic',
#          'notebook',
#          'widgetsnbextension',
#          'ipywidgets',
#          'cufflinks',
#          'cufflinks',
#          'blessed',
#          'inquirer',
#          'lightning',
#          'lightning-cloud',
#          'lightning',
#          'gdown',
#          'retina-face',
#          'astunparse',
#          'tensorflow',
#          'retina-face',
#          'google-pasta',
#          'tensorflow',
#          'retina-face',
#          'grpcio',
#          'tensorflow',
#          'retina-face',
#          'keras-preprocessing',
#          'tensorflow',
#          'retina-face',
#          'tensorflow',
#          'retina-face',
#          'google-auth',
#          'tensorboard',
#          'tensorflow',
#          'retina-face'],
#  'sniffio': ['anyio',
#              'jupyter-server',
#              'nbclassic',
#              'notebook',
#              'widgetsnbextension',
#              'ipywidgets',
#              'cufflinks'],
#  'soupsieve': ['beautifulsoup4', 'conda-build'],
#  'stack-data': ['ipython', 'cufflinks'],
#  'starlette': ['fastapi',
#                'lightning',
#                'lightning',
#                'starsessions',
#                'lightning'],
#  'starsessions': ['lightning'],
#  'sympy': ['torch', 'pytorch-lightning', 'lightning'],
#  'tenacity': ['plotly', 'chart-studio'],
#  'tensorboard': ['tensorflow', 'retina-face'],
#  'tensorboard-data-server': ['tensorboard', 'tensorflow', 'retina-face'],
#  'tensorboard-plugin-wit': ['tensorboard', 'tensorflow', 'retina-face'],
#  'tensorflow': ['retina-face'],
#  'tensorflow-estimator': ['tensorflow', 'retina-face'],
#  'tensorflow-io-gcs-filesystem': ['tensorflow', 'retina-face'],
#  'termcolor': ['tensorflow', 'retina-face'],
#  'terminado': ['jupyter-server',
#                'nbclassic',
#                'notebook',
#                'widgetsnbextension',
#                'ipywidgets',
#                'cufflinks',
#                'nbclassic',
#                'notebook',
#                'widgetsnbextension',
#                'ipywidgets',
#                'cufflinks',
#                'notebook',
#                'widgetsnbextension',
#                'ipywidgets',
#                'cufflinks'],
#  'threadpoolctl': ['scikit-learn'],
#  'tinycss2': ['nbconvert',
#               'jupyter-server',
#               'nbclassic',
#               'notebook',
#               'widgetsnbextension',
#               'ipywidgets',
#               'cufflinks'],
#  'toml': ['sip'],
#  'tomli': ['conda-build', 'jupyterlab'],
#  'toolz': [],
#  'torch': ['pytorch-lightning',
#            'lightning',
#            'torchmetrics',
#            'pytorch-lightning',
#            'lightning',
#            'lightning',
#            'simple-hierarchy',
#            'torchaudio',
#            'torchvision'],
#  'torchaudio': [],
#  'torchmetrics': ['pytorch-lightning', 'lightning', 'lightning'],
#  'torchview': [],
#  'torchvision': [],
#  'tornado': ['jupyter-client',
#              'ipykernel',
#              'ipywidgets',
#              'cufflinks',
#              'ipykernel',
#              'ipywidgets',
#              'cufflinks',
#              'terminado',
#              'jupyter-server',
#              'nbclassic',
#              'notebook',
#              'widgetsnbextension',
#              'ipywidgets',
#              'cufflinks',
#              'jupyter-server',
#              'nbclassic',
#              'notebook',
#              'widgetsnbextension',
#              'ipywidgets',
#              'cufflinks',
#              'nbclassic',
#              'notebook',
#              'widgetsnbextension',
#              'ipywidgets',
#              'cufflinks',
#              'notebook',
#              'widgetsnbextension',
#              'ipywidgets',
#              'cufflinks',
#              'jupyterlab'],
#  'tqdm': ['anaconda-client',
#           'conda',
#           'conda-build',
#           'conda-build',
#           'fastdup',
#           'pytorch-lightning',
#           'lightning',
#           'lightning',
#           'nltk',
#           'gdown',
#           'retina-face',
#           'webdriver-manager'],
#  'traitlets': ['jupyter-core',
#                'nbformat',
#                'anaconda-client',
#                'nbformat',
#                'anaconda-client',
#                'matplotlib-inline',
#                'ipython',
#                'cufflinks',
#                'ipython',
#                'cufflinks',
#                'comm',
#                'ipykernel',
#                'ipywidgets',
#                'cufflinks',
#                'jupyter-client',
#                'ipykernel',
#                'ipywidgets',
#                'cufflinks',
#                'ipykernel',
#                'ipywidgets',
#                'cufflinks',
#                'ipywidgets',
#                'cufflinks',
#                'nbclient',
#                'nbconvert',
#                'jupyter-server',
#                'nbclassic',
#                'notebook',
#                'widgetsnbextension',
#                'ipywidgets',
#                'cufflinks',
#                'nbconvert',
#                'jupyter-server',
#                'nbclassic',
#                'notebook',
#                'widgetsnbextension',
#                'ipywidgets',
#                'cufflinks',
#                'jupyter-server',
#                'nbclassic',
#                'notebook',
#                'widgetsnbextension',
#                'ipywidgets',
#                'cufflinks',
#                'nbclassic',
#                'notebook',
#                'widgetsnbextension',
#                'ipywidgets',
#                'cufflinks',
#                'notebook',
#                'widgetsnbextension',
#                'ipywidgets',
#                'cufflinks',
#                'jupyter-console',
#                'jupyter',
#                'qtconsole',
#                'jupyter',
#                'lightning'],
#  'typing-extensions': ['ipython',
#                        'cufflinks',
#                        'pydantic',
#                        'fastapi',
#                        'lightning',
#                        'starlette',
#                        'fastapi',
#                        'lightning',
#                        'lightning-utilities',
#                        'lightning',
#                        'torch',
#                        'pytorch-lightning',
#                        'lightning',
#                        'pytorch-lightning',
#                        'lightning',
#                        'lightning',
#                        'tensorflow',
#                        'retina-face'],
#  'unicodedata2': [],
#  'urllib3': ['requests',
#              'conda-package-streaming',
#              'conda-package-handling',
#              'anaconda-client',
#              'anaconda-client',
#              'sentry-sdk',
#              'fastdup',
#              'sentry-sdk',
#              'fastdup',
#              'selenium',
#              'helium',
#              'lightning-cloud',
#              'lightning',
#              'lightning'],
#  'uvicorn': ['lightning-cloud', 'lightning', 'lightning'],
#  'wcwidth': ['prompt-toolkit',
#              'ipython',
#              'cufflinks',
#              'blessed',
#              'inquirer',
#              'lightning'],
#  'webdriver-manager': [],
#  'webencodings': ['bleach',
#                   'nbconvert',
#                   'jupyter-server',
#                   'nbclassic',
#                   'notebook',
#                   'widgetsnbextension',
#                   'ipywidgets',
#                   'cufflinks',
#                   'tinycss2',
#                   'nbconvert',
#                   'jupyter-server',
#                   'nbclassic',
#                   'notebook',
#                   'widgetsnbextension',
#                   'ipywidgets',
#                   'cufflinks'],
#  'websocket-client': ['jupyter-server',
#                       'nbclassic',
#                       'notebook',
#                       'widgetsnbextension',
#                       'ipywidgets',
#                       'cufflinks',
#                       'lightning-cloud',
#                       'lightning',
#                       'lightning'],
#  'websockets': ['lightning'],
#  'werkzeug': ['tensorboard', 'tensorflow', 'retina-face'],
#  'wheel': ['astunparse',
#            'tensorflow',
#            'retina-face',
#            'tensorboard',
#            'tensorflow',
#            'retina-face'],
#  'widgetsnbextension': ['ipywidgets', 'cufflinks'],
#  'win-inet-pton': [],
#  'wrapt': ['tensorflow', 'retina-face'],
#  'yarl': ['aiohttp'],
#  'zipp': ['importlib-metadata',
#           'jupyter-client',
#           'ipykernel',
#           'ipywidgets',
#           'cufflinks',
#           'importlib-resources',
#           'matplotlib'],
#  'zstandard': ['conda-package-streaming',
#                'conda-package-handling',
#                'anaconda-client']}

# %%
import subprocess

def get_pip_package_list():
    command = ['mamba', 'list']
    result = subprocess.run(command, capture_output=True, text=True)
    output_lines = result.stdout.strip().split('\n')[2:]  # Remove header rows

    package_list = []
    for line in output_lines:
        if line.count('pypi') >= 2:
            package_name = line.split()[0]
            package_list.append(package_name)

    return package_list
# Out:
# ['fastdup', 'image-to-numpy', 'pipdeptree', 'simple-hierarchy', 'torchaudio', 'torchvision']

# %%
import argparse

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument('-p', '--packages', nargs='+', required=True, help='passing x package(s) will output x requires/required-by descriptions')
    parser.add_argument('-dd', '--deep-dependencies', help='recursively output all packages which package(s) requires')
    parser.add_argument('-drb', '--deep-required-by', help='recursively output all packages which depend on package(s)')
    parser.add_argument('-spi', '--show-package-installer', help='in the output, displays the packages installed with pip vs mamba (conda)')
    args = parser.parse_args()

    result = subprocess.run(['pipdeptree', '--json-tree'], capture_output=True, text=True)
    result_json = json.loads(result)

    # Set to store package dicts
    package_name_to_reqs = dict()
    package_name_to_req_by = dict()
    deep_reqs = False if args.deep_dependencies is None else True
    deep_req_by = False if args.deep_required_by is None else True

    # Traverse the JSON data recursively to fill in package_name_to_reqs and package_name_to_req_by
    for cur_package_dict in result_json:
        add_dependencies(cur_package_dict)

    if args.show_package_installer is not None:
        pip_packages_installed = get_pip_package_list()
    else:
        print('since -spi is not passed, will assume all packages are mamba/conda installed:')
        pip_packages_installed = []

    for package_name in args.packages:
        print('package name: ', package_name)
        print()
        print('dependencies:')
        print('pip installed:')
        pprint([pkg for pkg in package_name_to_reqs[package_name] if pkg in pip_packages_installed])
        print('mamba/conda installed:')
        pprint([pkg for pkg in package_name_to_reqs[package_name] if pkg not in pip_packages_installed])
        print()
        print('dependencies:')
        print('pip installed:')
        pprint([pkg for pkg in package_name_to_reqs[package_name] if pkg in pip_packages_installed])
        print('mamba/conda installed:')
        pprint([pkg for pkg in package_name_to_reqs[package_name] if pkg not in pip_packages_installed])
        print()
        print('required by:')
        print('pip installed:')
        pprint([pkg for pkg in package_name_to_req_by[package_name] if pkg in pip_packages_installed])
        print('mamba/conda installed:')
        pprint([pkg for pkg in package_name_to_req_by[package_name] if pkg not in pip_packages_installed])
        print()
        print()
# Out:
# usage: ipykernel_launcher.py [-h] [-p PACKAGES [PACKAGES ...]]
#                              [-dd DEEP_DEPENDENCIES] [-drb DEEP_REQUIRED_BY]
#                              [-spi SHOW_PACKAGE_INSTALLER]
# ipykernel_launcher.py: error: unrecognized arguments: --ip=127.0.0.1 --stdin=9011 --control=9009 --hb=9008 --Session.signature_scheme="hmac-sha256" --Session.key=b"7297d98e-5fad-49fb-9738-ef4ba0f48409" --shell=9010 --transport="tcp" --iopub=9012 --f=c:\Users\ashra\AppData\Roaming\jupyter\runtime\kernel-v2-40080ctk089z515Zq.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# d:\CS\projects\graduation_project\.mamba\lib\site-packages\IPython\core\interactiveshell.py:3513: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
